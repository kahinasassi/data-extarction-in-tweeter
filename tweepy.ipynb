# %% [markdown]
# <a href="https://colab.research.google.com/github/kahinasassi/data-extarction-in-tweeter/blob/main/tweepy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""

@author: sassikahina@gmail.com
"""

import tweepy as tw
import pandas as pd
import csv

# %%
#Twitter credentials for the app
consumer_key = "UvUY8ULhn8HW6h9TprRW53TBI"
consumer_secret = "4hnoV8jmoMuhtmOlFerF6PLTydb6TqLKiBW4Kv6KUF5fnaaQgl"
access_key= "1186631612211105801-Vf6dujFP2UW08QToO1p63ICBrTAxbJ"
access_secret = "mJqC05I86mh73ZQFkQv3mVGdNDRBCM5Jewq23lEfC03He"

#pass twitter credentials to tweepy
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tw.API(auth,wait_on_rate_limit=True)

# %%
#2018-02-22 done
#2019-12-13 done
#2020-04-04 next

# Define the search term and the date_since date as variables
hashtag=["#hirak","#Hirak","لا_انتخابات_مع_العصابات","#يتنحاو_ڨاع","#حراك_18_اكتوبر","#الجزائر_لن_تنتخب","#يتنحاو_ڨاع","#العصابة_ترشح_رموزها#","#Algerie_Libre_Democratique","#Algerie","محاكمة_رموز_الفساد","#الجزائر_لن_تنتخب#","#libertedelapresse","تسقط_انتخابات_العصابات#",
         "#Yetna7aw_Ga3","محاكمة_العصابة","الله_لا_تربحكم#","‎#Alger","‎#coronavirusalgerie","‎‎#كورونا_الجزائر","‎#شد_دارك","‎#ريح_في_دارك","‎#الثورة_السلمية_مستمرة#","دولة_مدنية_ماشي_عسكرية#","الجزائر","#AlgeriaWindOfChange","‎#Algeria"]

date_since ="2019-12-13"
lang="fr"



liste=[]

for x in hashtag:   
            for tweet in tw.Cursor(api.search,q=x,
                                           lang=lang,
                                           since=date_since).items():
                
                try:
                    liste.append([tweet.created_at, tweet.text])       
                    print(tweet.text) 
                except tw.TweepError:
                    print("error one !!!!!!!!!!!!! ")
                    tweet_text = pd.DataFrame(data=liste,columns=['created_at', "tweet"])
                    export_csv = tweet_text.to_csv (r'/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/dataset/tweet_fr.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
           
                  

tweet_text = pd.DataFrame(data=liste,columns=['created_at', "tweet"])
export_csv = tweet_text.to_csv (r'/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/dataset/tweet_fr.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
               
print(liste)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# RT @Algerie360: Coronavirus Algérie : des algériens bloqués aux îles des Maldives lancent un appel aux autorités - https://t.co/CW9XbVjDUN…
# RT @jeune_afrique: De Tunis à Rabat, le double combat contre le coronavirus et les « fake news » https://t.co/tbztxIcq1T #COVID19 #Algerie…
# RT @Nime_BD: Merci aux médecins et personnels soignants. #restecheztoi #RESTEZCHEZVOUS #Covid_19 #كورونا #confinementjour23 #StayHome #Alge…
# RT @Nime_BD: Merci aux médecins et personnels soignants. #restecheztoi #RESTEZCHEZVOUS #Covid_19 #كورونا #confinementjour23 #StayHome #Alge…
# RT @CACIFrance: 🇩🇿🇪🇺🦠[Good News] - Merci !
# 👏L’Union européenne @UEFrance a annoncé, ce mercredi 8 avril, avoir accordé un soutien financie…
# RT @RSF_inter: 🔴#URGENT : en pleine pandémie de #Coronavirus, @khaleddrareni, correspondant de RSF en #Algérie
#  a été emprisonné. Son tort…
# ...
